# %%
import numpy as np
import matplotlib.pyplot as plt

Radius = 2.0
radius = 0.5
wplanet = 2.0
wmoon = 14.0
time = np.arange(0.0, 3.2, 0.02)

x0 = Radius * np.cos(wplanet * time)
y0 = Radius * np.sin(wplanet * time)

x = Radius * np.cos(wplanet * time) + radius * np.cos(wmoon * time)
y = Radius * np.sin(wplanet * time) + radius * np.sin(wmoon * time)

plt.plot(x, y, label='Moon')
plt.plot(x0, y0, label='Planet')
plt.xlabel('X')
plt.ylabel('Y')
plt.title('Motion of Planet and Moon')
plt.legend()
plt.grid()
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt
x = np.arange(0.0, 5.0, 0.001)
y = np.sin(30 * x) + np.sin(33 * x)
plt.ylabel("f(x) = sin(30x) + sin(33x)")
plt.xlabel("x")
plt.title("f(x) = sin(30x) + sin(33x)")
plt.plot(x, y)
plt.grid()

# %%
import numpy as np
import matplotlib.pyplot as plt

# Define parameters with descriptive names
G = 6.6743e-11  # Gravitational constant (optional, not used in this simplified model)
m_p = 1.0  # Mass of the planet (arbitrary unit)
m_m = 0.1  # Mass of the moon (relative to planet)
r_p = 4.0  # Radius of the planet's orbit
r_m = 1.0  # Radius of the moon's orbit around the planet
r_s = 0.125  # Radius of the satellite's orbit around the moon

# Define angular frequencies (not physically accurate in this simple model)
w_p = 2.0  # Angular frequency of the planet (assumed constant)
w_m = 27.26  # Angular frequency of the moon (assumed constant)
w_s = 200.0  # Angular frequency of the satellite (assumed constant)

# Define time parameters
t_start = 0.0
t_end = 3.2
dt = 0.02

# Create time array
t = np.arange(t_start, t_end + dt, dt)

# Calculate positions of planet, moon, and satellite (assuming circular motion)
x_p = r_p * np.cos(w_p * t)
y_p = r_p * np.sin(w_p * t)

x_m = x_p + r_m * np.cos(w_m * t)
y_m = y_p + r_m * np.sin(w_m * t)

x_s = x_m + r_s * np.cos(w_s * t)
y_s = y_m + r_s * np.sin(w_s * t)

# Plot the trajectories
plt.plot(x_p, y_p, label='Planet')
plt.plot(x_m, y_m, label='Moon')
plt.plot(x_s, y_s, label='Satellite')
plt.xlabel('X')
plt.ylabel('Y')
plt.title('Motion of Planet, Moon, and Satellite (Simplified Model)')
plt.legend()
plt.grid(True)
plt.show()
